-163.0), (32.0, -162.75), (32.0, -162.5), (32.0, -162.25)], [(32.25, -166.0), (32.25, -165.75), (32.25, -165.5), (32.25, -165.25), (32.25, -165.0), (32.25, -164.75), (32.25, -164.5), (32.25, -164.25), (32.25, -164.0), (32.25, -163.75), (32.25, -163.5), (32.25, -163.25), (32.25, -163.0), (32.25, -162.75), (32.25, -162.5), (32.25, -162.25)], [(32.5, -166.0), (32.5, -165.75), (32.5, -165.5), (32.5, -165.25), (32.5, -165.0), (32.5, -164.75), (32.5, -164.5), (32.5, -164.25), (32.5, -164.0), (32.5, -163.75), (32.5, -163.5), (32.5, -163.25), (32.5, -163.0), (32.5, -162.75), (32.5, -162.5), (32.5, -162.25)], [(32.75, -166.0), (32.75, -165.75), (32.75, -165.5), (32.75, -165.25), (32.75, -165.0), (32.75, -164.75), (32.75, -164.5), (32.75, -164.25), (32.75, -164.0), (32.75, -163.75), (32.75, -163.5), (32.75, -163.25), (32.75, -163.0), (32.75, -162.75), (32.75, -162.5), (32.75, -162.25)]],
    start_time=1757426400.0,
    end_time=1757502000.0
)

# %%
import torch
import numpy as np
import bittensor as bt
import openmeteo_requests
import pandas as pd

bt.logging.set_debug(True)


openmeteo_api = openmeteo_requests.Client()

coordinates = torch.Tensor(synapse.locations)
# start_time = to_timestamp(synapse.start_time)
# end_time = to_timestamp(synapse.end_time)
start_time = pd.Timestamp("2025-09-12 22:00:00")
end_time = pd.Timestamp("2025-09-13 19:00:00")
bt.logging.debug(
    f"Received request! Predicting {synapse.requested_hours} hours of {synapse.variable} for grid of shape {coordinates.shape}."
)

##########################################################################################################
# TODO (miner) you likely want to improve over this baseline of calling OpenMeteo by changing this section
latitudes, longitudes = coordinates.view(-1, 2).T
converter = get_converter(synapse.variable)

print(f"start time: {start_time.isoformat(timespec='minutes')}")
print(f"end time: {end_time.isoformat(timespec='minutes')}")
params = {
    "latitude": latitudes.tolist(),
    "longitude": longitudes.tolist(),
    "hourly": converter.om_name,
    "start_hour": start_time.isoformat(timespec="minutes"),
    "end_hour": end_time.isoformat(timespec="minutes"),
}
responses = openmeteo_api.weather_api(
    "https://api.open-meteo.com/v1/forecast", params=params, method="POST"
)

output = torch.Tensor(np.stack(
    [
        np.stack(
            [
                r.Hourly().Variables(i).ValuesAsNumpy() 
                for i in range(r.Hourly().VariablesLength())
            ],
            axis=-1
        )
        for r in responses
    ],
    axis=1
)).reshape(synapse.requested_hours, *coordinates.shape[:2], -1)
# [time, lat, lon] in case of single variable output
output = output.squeeze(dim=-1)
# Convert variable(s) to ERA5 units, combines variables for windspeed
output = converter.om_to_era5(output)

print(f"output: {output}")
# Out:
# start time: 2025-09-12T22:00
# end time: 2025-09-13T19:00
# output: tensor([[[298.9500, 299.1500, 298.9500,  ..., 298.9500, 299.0000, 299.0000],
#          [299.6000, 299.5000, 299.4000,  ..., 298.9000, 298.9000, 298.9500],
#          [299.4500, 299.4000, 299.3000,  ..., 298.7500, 298.8500, 298.9500],
#          ...,
#          [298.1000, 298.0500, 298.0500,  ..., 298.3000, 298.3000, 298.2500],
#          [298.6500, 298.7000, 298.2500,  ..., 298.1500, 298.0500, 298.0500],
#          [298.6500, 298.6500, 298.5500,  ..., 298.7000, 298.6000, 298.5500]],
#
#         [[298.9500, 299.1500, 298.9500,  ..., 298.9500, 299.0500, 299.1500],
#          [299.5000, 299.3500, 299.3000,  ..., 298.9000, 298.9500, 299.0500],
#          [299.5500, 299.5000, 299.4500,  ..., 298.8500, 298.9000, 299.0000],
#          ...,
#          [298.1500, 298.0500, 298.0500,  ..., 298.1500, 298.1000, 298.1000],
#          [298.7500, 298.7000, 298.5000,  ..., 298.7000, 298.3000, 298.3500],
# ...
